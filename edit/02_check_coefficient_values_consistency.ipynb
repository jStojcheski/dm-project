# %% [markdown]
# ### Проверка дали вредностите за коефициентите $\in [0, 100]$

# %%
import pandas as pd

# %%
df = pd.read_csv('dataset/Spenser_1_7_remove_v22_treshold.tsv', sep='\t')
df.head()
# Out:
#    CustomerID Calendarday  month PerformanceEvaluationPlanned  \
# 0   100000136  2017-05-01      5                            0
# 1   100000136  2017-05-04      5                            1
# 2   100000136  2017-05-08      5                            1
# 3   100000136  2017-05-11      5                            1
# 4   100000136  2017-05-12      5
#
#   PerformanceEvaluationExecuted PerformanceEvaluationAdHoc       TERRID  \
# 0                                                           Employee 44
# 1                             1                             Employee 44
# 2                             1                             Employee 44
# 3                             1                             Employee 44
# 4                                                           Employee 44
#
#   SAPECCSalesGroup  SAPECoeficient  APECoeficient  FPECoeficient SAMEDAYVISIT  \
# 0           Team 1             NaN            NaN            NaN
# 1           Team 1          90.987            NaN         90.987
# 2           Team 1          90.987            NaN         90.987
# 3           Team 1          90.987            NaN         90.987
# 4           Team 1             NaN         79.498         90.987
#
#   OVERDUE UNDERDUE  OK NOTOK STATUS OVERDUEDAYS
# 0
# 1
# 2
# 3                   ok           ok
# 4

# %%
cols = df.columns

# %% [markdown]
# #### Проверка за конзистентност на коефициентите

# %%
df_unc = pd.DataFrame(columns=cols)

for row in df.iterrows():
    if (row[1]['SAPECoeficient'] is not pd.np.nan and
        (row[1]['SAPECoeficient'] < 0 or row[1]['SAPECoeficient'] > 100)):
        df_unc = df_unc.append(pd.DataFrame(row[1]).transpose())
    elif (row[1]['APECoeficient'] is not pd.np.nan and
        (row[1]['APECoeficient'] < 0 or row[1]['APECoeficient'] > 100)):
        df_unc = df_unc.append(pd.DataFrame(row[1]).transpose())
    elif (row[1]['FPECoeficient'] is not pd.np.nan and
        (row[1]['FPECoeficient'] < 0 or row[1]['FPECoeficient'] > 100)):
        df_unc = df_unc.append(pd.DataFrame(row[1]).transpose())

# %%
df_unc
# Out:
#        CustomerID Calendarday month PerformanceEvaluationPlanned  \
# 595     100000209  2017-10-20    10
# 596     100000209  2017-10-24    10                            1
# 597     100000209  2017-10-31    11                            1
# 598     100000209  2017-11-07    11                            1
# 601     100000209  2017-11-28    12                            1
# 602     100000209  2017-12-05    12                            1
# 702     100000216  2017-10-20    10
# 714     100000216  2017-12-22    12
# 816     100000220  2017-10-20    10
# 826     100000220  2017-12-15    12
# 828     100000220  2017-12-22    12
# 2661    100000339  2017-07-20     7                            1
# 2662    100000339  2017-07-27     7                            1
# 2663    100000339  2017-08-03     8                            1
# 2666    100000339  2017-08-24     8                            1
# 2668    100000339  2017-08-31     9                            1
# 2672    100000339  2017-09-21     9                            1
# 2673    100000339  2017-09-28     9                            1
# 2674    100000339  2017-10-05    10                            1
# 2723    100000340  2017-11-16    11                            1
# 2724    100000340  2017-11-23    11                            1
# 2725    100000340  2017-11-30    12                            1
# 2726    100000340  2017-12-01    12
# 2727    100000340  2017-12-07    12                            1
# 2728    100000340  2017-12-14    12                            1
# 2729    100000340  2017-12-21    12                            1
# 2730    100000340  2017-12-28    12                            1
# 8622    100000805  2017-06-17     6
# 8747    100000810  2017-12-26    12                            1
# 8786    100000811  2017-12-25    12
# ...           ...         ...   ...                          ...
# 72123   100007250  2017-10-26    10                            1
# 72124   100007250  2017-11-02    11                            1
# 72125   100007250  2017-11-09    11                            1
# 72127   100007250  2017-11-23    11                            1
# 72128   100007250  2017-11-30    12                            1
# 72130   100007250  2017-12-14    12                            1
# 72131   100007250  2017-12-15    12
# 72132   100007250  2017-12-21    12                            1
# 72133   100007250  2017-12-28    12                            1
# 72261   100007273  2017-12-19    12                            1
# 77847   100008113  2017-12-28    12                            1
# 77877   100008115  2017-11-02    11                            1
# 80866   100008500  2017-07-20     7
# 80871   100008500  2017-08-16     8
# 81676   100008610  2017-05-02     5                            1
# 81685   100008610  2017-06-27     6                            1
# 81686   100008610  2017-07-04     7                            1
# 84711   100009135  2017-07-28     7
# 89302   100009768  2017-11-17    11                            1
# 89303   100009768  2017-11-24    11                            1
# 90903   100010131  2017-07-19     7
# 92733   100012604  2017-08-03     8                            1
# 92734   100012604  2017-08-10     8                            1
# 110094  100020218  2017-10-04    10                            1
# 110096  100020218  2017-10-18    10                            1
# 118929  100022547  2017-12-25    12
# 118930  100022547  2017-12-27    12                            1
# 128866  100023440  2017-10-19    10                            1
# 128867  100023440  2017-10-26    10                            1
# 128868  100023440  2017-11-02    11                            1
#
#        PerformanceEvaluationExecuted PerformanceEvaluationAdHoc       TERRID  \
# 595                                                           1  Employee 26
# 596                                1                             Employee 26
# 597                                1                             Employee 26
# 598                                1                             Employee 26
# 601                                1                             Employee 26
# 602                                1                             Employee 26
# 702                                                           1  Employee 26
# 714                                                           1  Employee 26
# 816                                                           1  Employee 26
# 826                                                           1  Employee 26
# 828                                                           1  Employee 26
# 2661                               1                              Employee 6
# 2662                               1                              Employee 6
# 2663                               1                              Employee 6
# 2666                               1                              Employee 6
# 2668                               1                              Employee 6
# 2672                               1                              Employee 6
# 2673                               1                              Employee 6
# 2674                               1                              Employee 6
# 2723                               1                              Employee 6
# 2724                               1                              Employee 6
# 2725                               1                              Employee 6
# 2726                                                              Employee 6
# 2727                               1                              Employee 6
# 2728                               1                              Employee 6
# 2729                               1                              Employee 6
# 2730                               1                              Employee 6
# 8622                                                             Employee 55
# 8747                               1                             Employee 26
# 8786                                                          1  Employee 26
# ...                              ...                        ...          ...
# 72123                              1                             Employee 30
# 72124                              1                             Employee 30
# 72125                              1                             Employee 30
# 72127                              1                             Employee 30
# 72128                              1                             Employee 30
# 72130                              1                             Employee 30
# 72131                                                            Employee 30
# 72132                              1                             Employee 30
# 72133                              1                             Employee 30
# 72261                              1                             Employee 30
# 77847                              1                             Employee 72
# 77877                              1                             Employee 73
# 80866                                                            Employee 55
# 80871                                                            Employee 55
# 81676                              1                             Employee 73
# 81685                              1                             Employee 73
# 81686                              1                             Employee 73
# 84711                                                         1  Employee 30
# 89302                              1                             Employee 52
# 89303                              1                             Employee 52
# 90903                                                            Employee 55
# 92733                              1                             Employee 30
# 92734                              1                             Employee 30
# 110094                             1                             Employee 52
# 110096                             1                             Employee 52
# 118929                                                        1  Employee 26
# 118930                             1                             Employee 26
# 128866                             1                             Employee 26
# 128867                             1                             Employee 26
# 128868                             1                             Employee 26
#
#        SAPECCSalesGroup SAPECoeficient APECoeficient FPECoeficient  \
# 595              Team 5          100.4           NaN          98.4
# 596              Team 5          100.4           NaN          98.4
# 597              Team 5          100.4           NaN         100.4
# 598              Team 5          100.4           NaN         100.4
# 601              Team 5          100.4           NaN         97.25
# 602              Team 5          100.4           NaN         97.25
# 702              Team 5          100.4           NaN        87.875
# 714              Team 5          100.4           NaN          91.1
# 816              Team 5          100.4           NaN        92.281
# 826              Team 5          100.4           NaN        94.305
# 828              Team 5          100.4           NaN        94.305
# 2661             Team 8          100.4           NaN        99.677
# 2662             Team 8          100.4           NaN        99.677
# 2663             Team 8          100.4           NaN          50.2
# 2666             Team 8          100.4           NaN          50.2
# 2668             Team 8          100.4           NaN        66.933
# 2672             Team 8          100.4           NaN        66.933
# 2673             Team 8          100.4           NaN        66.933
# 2674             Team 8          100.4           NaN        73.696
# 2723             Team 8          100.4           NaN        97.079
# 2724             Team 8          100.4           NaN        97.079
# 2725             Team 8          100.4           NaN         100.4
# 2726             Team 8            NaN         100.4         100.4
# 2727             Team 8          100.4           NaN         100.4
# 2728             Team 8          100.4           NaN         100.4
# 2729             Team 8          100.4           NaN         100.4
# 2730             Team 8          100.4           NaN         100.4
# 8622            Team 11            NaN         100.4        81.657
# 8747             Team 5          100.4           NaN        96.149
# 8786             Team 5          100.4           NaN          93.5
# ...                 ...            ...           ...           ...
# 72123            Team 5          100.4           NaN         100.4
# 72124            Team 5          100.4           NaN         100.4
# 72125            Team 5          100.4           NaN         100.4
# 72127            Team 5          100.4           NaN         100.4
# 72128            Team 5          100.4           NaN         100.4
# 72130            Team 5          100.4           NaN         100.4
# 72131            Team 5            NaN        91.267         100.4
# 72132            Team 5          100.4           NaN         100.4
# 72133            Team 5          100.4           NaN         100.4
# 72261            Team 5          100.4           NaN        74.912
# 77847            Team 3          100.4           NaN          77.2
# 77877            Team 3          100.4           NaN         81.05
# 80866           Team 11            NaN         100.4        66.482
# 80871           Team 11            NaN         100.4        59.341
# 81676            Team 3          100.4           NaN         99.15
# 81685            Team 3          100.4           NaN         99.15
# 81686            Team 3          100.4           NaN         99.05
# 84711            Team 5          100.4           NaN        43.086
# 89302            Team 2          100.4           NaN          97.4
# 89303            Team 2          100.4           NaN          97.4
# 90903           Team 11            NaN         100.4         75.68
# 92733            Team 5          100.4           NaN        98.884
# 92734            Team 5          100.4           NaN        98.884
# 110094           Team 2          100.4           NaN         88.88
# 110096           Team 2          100.4           NaN         88.88
# 118929           Team 5          100.4           NaN        91.925
# 118930           Team 5          100.4           NaN        91.925
# 128866           Team 5          100.4           NaN        90.632
# 128867           Team 5          100.4           NaN        90.632
# 128868           Team 5          100.4           NaN         100.4
#
#        SAMEDAYVISIT  OVERDUE UNDERDUE  OK   NOTOK   STATUS OVERDUEDAYS
# 595
# 596
# 597
# 598
# 601
# 602
# 702
# 714
# 816
# 826
# 828
# 2661
# 2662
# 2663
# 2666                                       not ok   not ok
# 2668                 overdue                       overdue           9
# 2672
# 2673
# 2674
# 2723
# 2724
# 2725                                   ok               ok
# 2726
# 2727
# 2728
# 2729
# 2730
# 8622
# 8747
# 8786
# ...             ...      ...      ...  ..     ...      ...         ...
# 72123
# 72124
# 72125
# 72127
# 72128
# 72130                                  ok               ok
# 72131
# 72132
# 72133
# 72261
# 77847
# 77877
# 80866
# 80871
# 81676
# 81685
# 81686
# 84711
# 89302
# 89303
# 90903
# 92733
# 92734
# 110094
# 110096
# 118929
# 118930
# 128866
# 128867
# 128868
#
# [102 rows x 18 columns]

# %%
print(len(df_unc), 'редици со неконзистентни вредности за коефициентите')
# Out:
# 102 редици со неконзистентни вредности за коефициентите

# %% [markdown]
# #### Зачувување на редиците со неконзистентни коефициенти

# %%
df_unc.to_csv('subsets/unconsistent_coefficients.tsv', sep='\t')
