# %%
import pandas as pd
import numpy as np
import sklearn as skl

# %%
df = pd.read_csv('dataset/Feature_vectors_customer_month_normalized.tsv', sep='\t')

# %%
df
# Out:
#        CustomerID  Month  No_planned_visits  No_executed_visits  \
# 0       100000136      5           0.466667            0.538462
# 1       100000136      6           0.533333            0.615385
# 2       100000136      7           0.266667            0.307692
# 3       100000136      8           0.533333            0.615385
# 4       100000136      9           0.600000            0.692308
# 5       100000136     10           0.400000            0.461538
# 6       100000136     11           0.333333            0.384615
# 7       100000136     12           0.600000            0.692308
# 8       100000141      5           0.466667            0.538462
# 9       100000141      6           0.533333            0.615385
# 10      100000141      7           0.600000            0.230769
# 11      100000141      9           0.133333            0.076923
# 12      100000142      5           0.266667            0.307692
# 13      100000142      6           0.133333            0.153846
# ...

# %%
no_planned = df.No_planned_visits.values
no_executed = df.No_executed_visits

# %%
np.dot((no_planned - np.mean(no_planned)), (no_executed - np.mean(no_executed)))/((len(no_planned) - 1) * np.std(no_planned) * np.std(no_executed))
# Out:
# 0.9596376099501619
