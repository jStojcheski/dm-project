# %% [markdown]
# ### Отстранување на атрибутите V22 и TRESHOLD

# %%
import pandas as pd

# %%
df = pd.read_csv('dataset/Spenser_1_6_str_to_float_coefficients.tsv',
                 delimiter='\t')
df = df.drop(['V22', 'TRESHOLD'], axis=1)
df
# Out:
#         CustomerID Calendarday  month PerformanceEvaluationPlanned  \
# 0        100000136  2017-05-01      5                            0
# 1        100000136  2017-05-04      5                            1
# 2        100000136  2017-05-08      5                            1
# 3        100000136  2017-05-11      5                            1
# 4        100000136  2017-05-12      5
# 5        100000136  2017-05-15      5                            1
# 6        100000136  2017-05-18      5                            1
# 7        100000136  2017-05-22      5                            1
# 8        100000136  2017-05-25      5                            1
# 9        100000136  2017-05-29      6                            1
# 10       100000136  2017-06-01      6                            1
# 11       100000136  2017-06-05      6                            1
# 12       100000136  2017-06-08      6                            1
# ...

# %%
df.to_csv('dataset/Spenser_1_7_remove_v22_treshold.tsv',
          sep='\t', index=None)
